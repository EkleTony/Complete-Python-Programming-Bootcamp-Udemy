# %% [markdown]
# # Comparison Operators
#
# This operators helps us to compare variables and output a Boolean value (true or False)
#
# * the table below gives a comprehensive explanation
# ![operators.JPG](attachment:operators.JPG)

# %%
2 ==2
# Out:
# True

# %%
1==1
# Out:
# True

# %%
1==0
# Out:
# False

# %%
# not equal

# %%
2!=9
# Out:
# True

# %%
'T' != 't'
# Out:
# True

# %%
"t" == 't'
# Out:
# True

# %%
# greater than

# %%
2>4
# Out:
# False

# %%
2<4
# Out:
# True

# %%
2<1
# Out:
# False

# %%
2 >=2
# Out:
# True

# %%
2>=1
# Out:
# True

# %%
2<=9
# Out:
# True

# %%
3<=1
# Out:
# False
